# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/rckyi/Documents/GitHub/hackathon_space_effector'

# %%
results_path = '/Users/rckyi/Documents/results'

# %%
os.listdir(results_path)
# Out:
# ['training_perf_data.csv', 'panda_dgm_v1.pth']

# %%
train_perf_data_path = '/Users/rckyi/Documents/results/training_perf_data.csv'

# %%
train_perf_data_path
# Out:
# '/Users/rckyi/Documents/results/training_perf_data.csv'

# %%
search_term = "time,t_loss_pde,t_loss_term,t_loss"

count = 0
with open(train_perf_data_path, 'r') as file:
    for line in file:        
        if search_term in line:
            print(f"Found: {line.strip()} at line {count}")
        count +=1
# Out:
# Found: time,t_loss_pde,t_loss_term,t_loss at line 15
# Found: time,t_loss_pde,t_loss_term,t_loss at line 33

# %%
print(count)
# Out:
# 3034

# %%
df = pd.read_csv(train_perf_data_path, header=33)

# %%
df
# Out:
#        time   t_loss_pde  t_loss_term       t_loss
# 0        10     9.870241    15.431171  1543.126978
# 1        20   611.437714    15.637065  1564.317944
# 2        30   224.932638    14.711005  1471.325439
# 3        40   204.608083    12.114714  1211.675995
# 4        50     8.168553    13.001354  1300.143518
# ...     ...          ...          ...          ...
# 2995  29960  4722.873413     0.203046    25.027511
# 2996  29970  4320.528552     0.199270    24.247537
# 2997  29980  6057.455762     0.194105    25.467924
# 2998  29990  5178.533057     0.215723    26.750839
# 2999  30000  7090.602710     0.239220    31.012626
#
# [3000 rows x 4 columns]

# %%
import math

# %%
x = df['time']
y = df['t_loss']

# %%
# Create the plot
plt.plot(x, y)

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_pde'])

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_term'])

# Display the plot
plt.show()

# %%
2/.02
# Out:
# 100.0
