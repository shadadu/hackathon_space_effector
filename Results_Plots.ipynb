# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/rckyi/Documents/GitHub/hackathon_space_effector'

# %%
results_path = '/Users/rckyi/Documents/results'

# %%
os.listdir(results_path)
# Out:
# ['.DS_Store', 'training_perf_data.csv', 'backup', 'panda_dgm_v1.pth']

# %%
train_perf_data_path = '/Users/rckyi/Documents/results/training_perf_data.csv'

# %%
train_perf_data_path
# Out:
# '/Users/rckyi/Documents/results/training_perf_data.csv'

# %%
search_term = "time,t_loss_pde,t_loss_term,t_loss"

count = 0
with open(train_perf_data_path, 'r') as file:
    for line in file:        
        if search_term in line:
            print(f"Found: {line.strip()} at line {count}")
        count +=1
# Out:
# Found: time,t_loss_pde,t_loss_term,t_loss at line 0

# %%
print(count)
# Out:
# 601

# %%
df = pd.read_csv(train_perf_data_path, header=0)

# %%
df
# Out:
#      time  t_loss_pde  t_loss_term       t_loss
# 0      10    5.073972    17.289873  1734.061230
# 1      20    6.699271    15.522009  1558.900171
# 2      30   73.324536    12.284323  1301.756775
# 3      40   69.415063     7.957550   865.170099
# 4      50   68.647748     5.800904   648.738116
# ..    ...         ...          ...          ...
# 595  5960   44.732752     3.862063   430.939078
# 596  5970   27.823614     3.818021   409.625717
# 597  5980   92.775094     3.754430   468.218094
# 598  5990   29.849278     3.489347   378.783971
# 599  6000   82.951318     3.489621   431.913437
#
# [600 rows x 4 columns]

# %%
import math

# %%
x = df['time']
y = df['t_loss']

# %%
# Create the plot
plt.plot(x, y)

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_pde'])

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_term'])

# Display the plot
plt.show()

# %%
2/.02
# Out:
# 100.0
