# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/rckyi/Documents/GitHub/hackathon_space_effector'

# %%
results_path = '/Users/rckyi/Documents/results'

# %%
os.listdir(results_path)
# Out:
# ['.DS_Store', 'training_perf_data.csv', 'backup', 'panda_dgm_v1.pth']

# %%
train_perf_data_path = '/Users/rckyi/Documents/results/training_perf_data.csv'

# %%
train_perf_data_path
# Out:
# '/Users/rckyi/Documents/results/training_perf_data.csv'

# %%
search_term = "time,t_loss_pde,t_loss_term,t_loss"

count = 0
with open(train_perf_data_path, 'r') as file:
    for line in file:        
        if search_term in line:
            print(f"Found: {line.strip()} at line {count}")
        count +=1
# Out:
# Found: time,t_loss_pde,t_loss_term,t_loss at line 46

# %%
print(count)
# Out:
# 6047

# %%
df = pd.read_csv(train_perf_data_path, header=46)

# %%
df
# Out:
#        time    t_loss_pde  t_loss_term        t_loss
# 0        10     48.388890    88.249276  88297.664062
# 1        20     91.413232    90.116890  90208.304688
# 2        30     82.691387    80.683515  80766.208854
# 3        40    166.299704    68.638138  68804.438021
# 4        50    980.885382    38.489846  39470.730339
# ...     ...           ...          ...           ...
# 5995  59960  44367.082505    12.896370  57263.451644
# 5996  59970   1370.527655    11.522534  12893.061784
# 5997  59980   3558.178099    12.212185  15770.362956
# 5998  59990   6868.814237     9.005203  15874.016536
# 5999  60000   5999.023118    12.496453  18495.476042
#
# [6000 rows x 4 columns]

# %%
import math

# %%
x = df['time']
y = df['t_loss']

# %%
# Create the plot
plt.plot(x, y)

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_pde'])

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_term'])

# Display the plot
plt.show()

# %%
2/.02
# Out:
# 100.0
