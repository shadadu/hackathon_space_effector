# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
os.getcwd()
# Out:
# '/home/shad/Documents/Git/hackathon_space_effector'

# %%
results_path = '/home/shad/Documents/results'

# %%
os.listdir(results_path)
# Out:
# ['panda_dgm_v1.pth', 'results_archive']

# %%
train_perf_data_path = results_path + '/training_perf_data.csv'

# %%
train_perf_data_path
# Out:
# '/home/shad/Documents/results/training_perf_data.csv'

# %%
search_term = "time,t_loss_pde,t_loss_term,t_loss"

count = 0
with open(train_perf_data_path, 'r') as file:
    for line in file:        
        if search_term in line:
            print(f"Found: {line.strip()} at line {count}")
        count +=1
# Out:
# Found: time,t_loss_pde,t_loss_term,t_loss_tc,t_loss at line 27

# %%
print(count)

# %%
df = pd.read_csv(train_perf_data_path, header=27)

# %%
df
# Out:
#       time  t_loss_pde  t_loss_term  t_loss_tc     t_loss
# 0       50    0.117827    13.468232  12.858408  11.917348
# 1      100    0.050172    13.449478  13.229675   5.151655
# 2      150    0.041654    12.880444  12.680770   4.294168
# 3      200    0.038979    13.286733  13.162356   4.030724
# 4      250    0.032806    13.270458  13.380157   3.413287
# ..     ...         ...          ...        ...        ...
# 995  49800    0.000482     4.002017  13.475425   0.088245
# 996  49850    0.000457     3.929695  13.125034   0.085015
# 997  49900    0.000485     3.968699  13.213444   0.088185
# 998  49950    0.000442     3.909008  12.889378   0.083327
# 999  50000    0.000595     3.888368  13.058131   0.098336
#
# [1000 rows x 5 columns]

# %%
import math

# %%
x = df['time']
y = df['t_loss']

# %%
x
# Out:
# 0         50
# 1        100
# 2        150
# 3        200
# 4        250
#        ...
# 995    49800
# 996    49850
# 997    49900
# 998    49950
# 999    50000
# Name: time, Length: 1000, dtype: int64

# %%
# Create the plot
plt.plot(x, y)

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_pde'])

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_term'])

# Display the plot
plt.show()

# %%
# Create the plot
plt.plot(x, df['t_loss_tc'])

# Display the plot
plt.show()
