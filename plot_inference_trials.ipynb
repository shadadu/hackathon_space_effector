# %%
import os
import sys

# %%
os.getcwd()
# Out:
# '/home/shad/Git/hackathon_space_effector'

# %%
work_dir = os.getcwd()
os.listdir(work_dir)
# Out:
# ['plot_inference_trials.ipynb',
#  '.agents',
#  'astrobee_grasp',
#  'Results_Plots.ipynb',
#  '.venv-jax',
#  '.idea',
#  'stop.sh',
#  'post_inference_trials.sh',
#  'plots',
#  '.gitattributes',
#  'moveit_build',
#  'README.md',
#  'CUDA_ERROR_FIX.md',
#  '.ipynb_checkpoints',
#  'bring_up.sh',
#  'frames.pdf',
#  'Det_Neural_Net_Dims.ipynb',
#  'setup_training_env.sh',
#  '.gitignore',
#  'Dockerfile',
#  'utils',
#  'load_pretrained_mdl_docker_micro_g.sh',
#  'requirements.txt',
#  'load_pretrained_mdl_docker.sh',
#  '.codex',
#  '.git',
#  'post_training_micro_g.sh',
#  'post_training.sh']
